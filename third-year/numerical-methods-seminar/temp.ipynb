# %%
# !pip install webgui_jupyter_widgets
# !pip install ngsolve
# Out:
# Requirement already satisfied: webgui_jupyter_widgets in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (0.2.37)
# Requirement already satisfied: ipywidgets>=7.0.0 in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from webgui_jupyter_widgets) (8.1.5)
# Requirement already satisfied: comm>=0.1.3 in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from ipywidgets>=7.0.0->webgui_jupyter_widgets) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from ipywidgets>=7.0.0->webgui_jupyter_widgets) (8.29.0)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from ipywidgets>=7.0.0->webgui_jupyter_widgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from ipywidgets>=7.0.0->webgui_jupyter_widgets) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from ipywidgets>=7.0.0->webgui_jupyter_widgets) (3.0.13)
# Requirement already satisfied: decorator in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->webgui_jupyter_widgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->webgui_jupyter_widgets) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->webgui_jupyter_widgets) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->webgui_jupyter_widgets) (3.0.48)
# Requirement already satisfied: pygments>=2.4.0 in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->webgui_jupyter_widgets) (2.18.0)
# Requirement already satisfied: stack-data in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->webgui_jupyter_widgets) (0.6.2)
# Requirement already satisfied: pexpect>4.3 in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->webgui_jupyter_widgets) (4.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=7.0.0->webgui_jupyter_widgets) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets>=7.0.0->webgui_jupyter_widgets) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets>=7.0.0->webgui_jupyter_widgets) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.0.0->webgui_jupyter_widgets) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.0.0->webgui_jupyter_widgets) (2.4.1)
# Requirement already satisfied: pure-eval in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.0.0->webgui_jupyter_widgets) (0.2.3)
# Requirement already satisfied: six>=1.12.0 in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from asttokens>=2.1.0->stack-data->ipython>=6.1.0->ipywidgets>=7.0.0->webgui_jupyter_widgets) (1.16.0)
# Collecting ngsolve
#   Downloading ngsolve-6.2.2406-cp312-cp312-macosx_10_15_universal2.whl.metadata (176 bytes)
# Collecting netgen-mesher==6.2.2406 (from ngsolve)
#   Downloading netgen_mesher-6.2.2406-cp312-cp312-macosx_10_15_universal2.whl.metadata (197 bytes)
# Collecting netgen-occt==7.8.1 (from netgen-mesher==6.2.2406->ngsolve)
#   Downloading netgen_occt-7.8.1-py3-none-macosx_11_0_arm64.whl.metadata (3.7 kB)
# Downloading ngsolve-6.2.2406-cp312-cp312-macosx_10_15_universal2.whl (37.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.2/37.2 MB 21.3 MB/s eta 0:00:00m eta 0:00:010:01:01
# Downloading netgen_mesher-6.2.2406-cp312-cp312-macosx_10_15_universal2.whl (10.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 27.7 MB/s eta 0:00:00MB/s eta 0:00:01:01
# Downloading netgen_occt-7.8.1-py3-none-macosx_11_0_arm64.whl (19.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.8/19.8 MB 26.9 MB/s eta 0:00:00m eta 0:00:010:01:01
# Installing collected packages: netgen-occt, netgen-mesher, ngsolve
# Successfully installed netgen-mesher-6.2.2406 netgen-occt-7.8.1 ngsolve-6.2.2406

# %%
from ngsolve import *
from ngsolve.webgui import Draw
from netgen.occ import *

# !jupyter nbextension enable --py widgetsnbextension
# !jupyter nbextension install --py widgetsnbextension
# Out:
# usage: jupyter [-h] [--version] [--config-dir] [--data-dir] [--runtime-dir]
#                [--paths] [--json] [--debug]
#                [subcommand]
#
# Jupyter: Interactive Computing
#
# positional arguments:
#   subcommand     the subcommand to launch
#
# options:
#   -h, --help     show this help message and exit
#   --version      show the versions of core jupyter packages and exit
#   --config-dir   show Jupyter config dir
#   --data-dir     show Jupyter data dir
#   --runtime-dir  show Jupyter runtime dir
#   --paths        show all Jupyter paths. Add --json for machine-readable
#                  format.
#   --json         output paths as machine-readable json
#   --debug        output debug information about paths
#
# Available subcommands: console dejavu events execute kernel kernelspec lab
# labextension labhub migrate nbconvert notebook qtconsole run server
# troubleshoot trust
#
# Jupyter command `jupyter-nbextension` not found.
# usage: jupyter [-h] [--version] [--config-dir] [--data-dir] [--runtime-dir]
#                [--paths] [--json] [--debug]
#                [subcommand]
#
# Jupyter: Interactive Computing
#
# positional arguments:
#   subcommand     the subcommand to launch
#
# options:
#   -h, --help     show this help message and exit
#   --version      show the versions of core jupyter packages and exit
#   --config-dir   show Jupyter config dir
#   --data-dir     show Jupyter data dir
#   --runtime-dir  show Jupyter runtime dir
#   --paths        show all Jupyter paths. Add --json for machine-readable
#                  format.
#   --json         output paths as machine-readable json
#   --debug        output debug information about paths
#
# Available subcommands: console dejavu events execute kernel kernelspec lab
# labextension labhub migrate nbconvert notebook qtconsole run server
# troubleshoot trust
#
# Jupyter command `jupyter-nbextension` not found.

# %%
#show ipyvidegts version
# !pip show ipywidgets
#change version to 7.7.2 
# !pip install ipywidgets==8.0.4
# !pip install -U jupyterlab ipywidgets jupyterlab-widgets
# Out:
# Requirement already satisfied: jupyterlab in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (4.3.2)
# Requirement already satisfied: ipywidgets in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (8.0.4)
# Collecting ipywidgets
#   Using cached ipywidgets-8.1.5-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: jupyterlab-widgets in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (3.0.13)
# Requirement already satisfied: async-lru>=1.0.0 in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from jupyterlab) (2.0.4)
# Requirement already satisfied: httpx~=0.28.0 in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from jupyterlab) (0.28.0)
# Requirement already satisfied: ipykernel>=6.5.0 in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from jupyterlab) (6.29.5)
# Requirement already satisfied: jinja2>=3.0.3 in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from jupyterlab) (3.1.4)
# Requirement already satisfied: jupyter-core in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from jupyterlab) (5.7.2)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from jupyterlab) (2.2.5)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from jupyterlab) (2.14.2)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from jupyterlab) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from jupyterlab) (0.2.4)
# Requirement already satisfied: packaging in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from jupyterlab) (24.1)
# Requirement already satisfied: setuptools>=40.8.0 in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from jupyterlab) (69.5.1)
# Requirement already satisfied: tornado>=6.2.0 in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from jupyterlab) (6.4.1)
# Requirement already satisfied: traitlets in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from jupyterlab) (5.14.3)
# Requirement already satisfied: comm>=0.1.3 in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from ipywidgets) (8.29.0)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from ipywidgets) (4.0.13)
# Requirement already satisfied: anyio in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from httpx~=0.28.0->jupyterlab) (4.6.2.post1)
# Requirement already satisfied: certifi in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from httpx~=0.28.0->jupyterlab) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from httpx~=0.28.0->jupyterlab) (1.0.7)
# Requirement already satisfied: idna in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from httpx~=0.28.0->jupyterlab) (3.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from httpcore==1.*->httpx~=0.28.0->jupyterlab) (0.14.0)
# Requirement already satisfied: appnope in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab) (0.1.4)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab) (8.6.3)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab) (0.1.7)
# Requirement already satisfied: nest-asyncio in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab) (1.6.0)
# Requirement already satisfied: psutil in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab) (5.9.0)
# Requirement already satisfied: pyzmq>=24 in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab) (25.1.2)
# Requirement already satisfied: decorator in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.48)
# Requirement already satisfied: pygments>=2.4.0 in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (2.18.0)
# Requirement already satisfied: stack-data in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.2)
# Requirement already satisfied: pexpect>4.3 in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from jinja2>=3.0.3->jupyterlab) (2.1.3)
# Requirement already satisfied: platformdirs>=2.5 in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from jupyter-core->jupyterlab) (4.3.6)
# Requirement already satisfied: argon2-cffi>=21.1 in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (23.1.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (7.16.4)
# Requirement already satisfied: nbformat>=5.3.0 in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (0.21.1)
# Requirement already satisfied: send2trash>=1.8.2 in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (1.8.0)
# Requirement already satisfied: babel>=2.10 in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab) (2.16.0)
# Requirement already satisfied: json5>=0.9.0 in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab) (0.10.0)
# Requirement already satisfied: jsonschema>=4.18.0 in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab) (4.23.0)
# Requirement already satisfied: requests>=2.31 in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab) (2.32.2)
# Requirement already satisfied: sniffio>=1.1 in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from anyio->httpx~=0.28.0->jupyterlab) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab) (21.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: attrs>=22.2.0 in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab) (0.22.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from jupyter-client>=6.1.12->ipykernel>=6.5.0->jupyterlab) (2.9.0.post0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab) (6.0.1)
# Requirement already satisfied: rfc3339-validator in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (6.2.0)
# Requirement already satisfied: defusedxml in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (0.10.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (1.5.1)
# Requirement already satisfied: tinycss2 in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab) (2.21.1)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab) (2.2.2)
# Requirement already satisfied: executing>=1.2.0 in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.4.1)
# Requirement already satisfied: pure-eval in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.3)
# Requirement already satisfied: six>=1.12.0 in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from asttokens>=2.1.0->stack-data->ipython>=6.1.0->ipywidgets) (1.16.0)
# Requirement already satisfied: webencodings in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (0.5.1)
# Requirement already satisfied: fqdn in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab) (1.5.1)
# Requirement already satisfied: isoduration in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab) (3.0.0)
# Requirement already satisfied: uri-template in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab) (24.11.1)
# Requirement already satisfied: cffi>=1.0.1 in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab) (1.17.1)
# Requirement already satisfied: soupsieve>1.2 in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (2.6)
# Requirement already satisfied: pycparser in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab) (2.22)
# Requirement already satisfied: arrow>=0.15.0 in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /Users/gemlorg/anaconda3/envs/ml/lib/python3.12/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab) (2.9.0.20241003)
# Using cached ipywidgets-8.1.5-py3-none-any.whl (139 kB)
# Installing collected packages: ipywidgets
#   Attempting uninstall: ipywidgets
#     Found existing installation: ipywidgets 8.0.4
#     Uninstalling ipywidgets-8.0.4:
#       Successfully uninstalled ipywidgets-8.0.4
# Successfully installed ipywidgets-8.1.5

# %%
shape = Box( (0,0,0), (5,3,2) )
shape.faces.Max(X).name="right"
Draw (shape);
# Out:
# WebGuiWidget(layout=Layout(height='500px', width='100%'), value={'ngsolve_version': 'Netgen x.x', 'mesh_dim': …
